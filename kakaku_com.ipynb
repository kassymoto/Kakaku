# %% [markdown]
# <a href="https://colab.research.google.com/github/kassymoto/Kakaku/blob/master/kakaku_com.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

class Kakaku:
  url = ""
  price = []
  date = []
  title = ""

# define urls
url = []
url.append(requests.get("http://kakaku.com/item/K0001014634/pricehistory/"))
url.append(requests.get("http://kakaku.com/item/K0001095746/pricehistory/"))
url.append(requests.get("http://kakaku.com/item/K0001095680/pricehistory/"))
url.append(requests.get("http://kakaku.com/item/K0001095676/pricehistory/"))
url.append(requests.get("http://kakaku.com/item/K0001019734/pricehistory/"))

# define class of kakaku num of urls
kakaku_list = []
for i in url:
  kakaku_tmp = Kakaku()
  kakaku_tmp.url = i
  kakaku_list.append(kakaku_tmp)
  
for kakaku in kakaku_list:
    soup = BeautifulSoup(kakaku.url.content, "html.parser")
    
    date = soup.find_all("td", class_="alignL")
    price = soup.find_all("td", class_="alignR itemviewColor06")
    
    title = soup.find("title").string.split(" ")[2:-1:]
    kakaku.title = str(" ".join(title))
    
    date_tmp = []
    price_tmp = []
    
    for i,j in zip(date[0::2],price):
        if(str(i.string)=="現在"):
            date_tmp.append(datetime.now().strftime('%Y-%m-%d'))
        else:
            date_tmp.append("".join(str(i.string).split(" ")[:-1:]).replace("年","-").replace("月","-").replace("日",""))
        price_tmp.append(int(str(j.string[1::]).replace(',','')))
    
    kakaku.date = date_tmp
    kakaku.price = price_tmp
    
"""
for i in kakaku_list:
    print(i.title)
    for j,k in zip(i.date,i.price):
        print(j,k)
    print()
    
"""
import pandas as pd
kakaku_Title = []
kakaku_Date = []
kakaku_Price = []

for i in kakaku_list:
    for j in range(len(i.date)):
        kakaku_Title.append(i.title)
    kakaku_Date += i.date
    kakaku_Price += i.price

kakaku_data = pd.DataFrame(
        {"Title":kakaku_Title,
         "Date":kakaku_Date,
         "Price":kakaku_Price})




import altair as alt

alt.Chart(kakaku_data, height=500 ,width=700).configure_legend(labelLimit=0).mark_line().encode(
        x="Date:T",
        y="Price:Q",
        color="Title:N"
        )
# Out:
# Chart({
#   config: Config({
#     legend: LegendConfig({
#       labelLimit: 0
#     })
#   }),
#   data:            Date  Price                                              Title
#   0    2019-01-21  13980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   1     2019-1-18  13980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   2      2019-1-8  14980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   3      2019-1-8  16799  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   4      2019-1-8  16800  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   5      2019-1-8  18160  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   6      2019-1-7  18468  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   7      2019-1-7  15980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   8      2019-1-7  15800  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   9      2019-1-7  15026  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   10     2019-1-7  14980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   11     2019-1-6  14980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   12     2019-1-3  14980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   13     2019-1-3  14980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   14     2019-1-2  14980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   15   2018-12-16  14980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   16   2018-12-12  14980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   17   2018-12-12  16178  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   18    2018-12-9  17798  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   19   2018-11-25  17798  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   20   2018-11-24  17623  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   21   2018-11-11  17798  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   22    2018-11-3  17798  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   23    2018-9-29  18338  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   24     2018-9-8  19980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   25     2018-9-3  19980  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   26    2018-8-29  22234  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   27    2018-8-29  22237  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   28    2018-8-23  22234  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   29     2018-8-9  22237  crucial Ballistix W4U2666BMS-8G [DDR4 PC4-2130...
#   ..          ...    ...                                                ...
#   171  2018-11-25   9032                           ANTEC NeoECO Gold NE750G
#   172  2018-11-23   9031                           ANTEC NeoECO Gold NE750G
#   173  2018-11-22   9032                           ANTEC NeoECO Gold NE750G
#   174  2018-11-22   9031                           ANTEC NeoECO Gold NE750G
#   175  2018-11-21   9032                           ANTEC NeoECO Gold NE750G
#   176  2018-11-21   9031                           ANTEC NeoECO Gold NE750G
#   177  2018-11-20   9032                           ANTEC NeoECO Gold NE750G
#   178  2018-11-20   9115                           ANTEC NeoECO Gold NE750G
#   179  2018-11-20   9031                           ANTEC NeoECO Gold NE750G
#   180   2018-11-7   9115                           ANTEC NeoECO Gold NE750G
#   181  2018-10-26   9121                           ANTEC NeoECO Gold NE750G
#   182  2018-10-25   9122                           ANTEC NeoECO Gold NE750G
#   183  2018-10-25   9205                           ANTEC NeoECO Gold NE750G
#   184  2018-10-22   9206                           ANTEC NeoECO Gold NE750G
#   185  2018-10-20   9291                           ANTEC NeoECO Gold NE750G
#   186  2018-10-20   9377                           ANTEC NeoECO Gold NE750G
#   187  2018-10-12   9454                           ANTEC NeoECO Gold NE750G
#   188  2018-10-10   9454                           ANTEC NeoECO Gold NE750G
#   189   2018-10-8   9980                           ANTEC NeoECO Gold NE750G
#   190   2018-10-5   9377                           ANTEC NeoECO Gold NE750G
#   191   2018-10-3   9377                           ANTEC NeoECO Gold NE750G
#   192   2018-10-1   9377                           ANTEC NeoECO Gold NE750G
#   193   2018-9-28   9460                           ANTEC NeoECO Gold NE750G
#   194   2018-9-28   9463                           ANTEC NeoECO Gold NE750G
#   195   2018-9-27   9550                           ANTEC NeoECO Gold NE750G
#   196   2018-9-26   9637                           ANTEC NeoECO Gold NE750G
#   197   2018-9-22   9638                           ANTEC NeoECO Gold NE750G
#   198   2018-9-22   9727                           ANTEC NeoECO Gold NE750G
#   199   2018-9-21   9805                           ANTEC NeoECO Gold NE750G
#   200   2018-9-21   9806                           ANTEC NeoECO Gold NE750G
#
#   [201 rows x 3 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'Title:N'
#     }),
#     x: X({
#       shorthand: 'Date:T'
#     }),
#     y: Y({
#       shorthand: 'Price:Q'
#     })
#   }),
#   height: 500,
#   mark: 'line',
#   width: 700
# })
