# %% [markdown]
# <a href="https://colab.research.google.com/github/kassymoto/Kakaku/blob/master/kakaku_com.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

class Kakaku:
  url = ""
  price = []
  date = []
  title = ""

# define urls
url = []
url.append(requests.get("http://kakaku.com/item/K0001014634/pricehistory/"))
url.append(requests.get("http://kakaku.com/item/K0001095746/pricehistory/"))
url.append(requests.get("http://kakaku.com/item/K0001095680/pricehistory/"))
url.append(requests.get("http://kakaku.com/item/K0001095676/pricehistory/"))
url.append(requests.get("http://kakaku.com/item/K0001019734/pricehistory/"))

# define class of kakaku num of urls
kakaku_list = []
for i in url:
  kakaku_tmp = Kakaku()
  kakaku_tmp.url = i
  kakaku_list.append(kakaku_tmp)
  
for kakaku in kakaku_list:
    soup = BeautifulSoup(kakaku.url.content, "html.parser")
    
    date = soup.find_all("td", class_="alignL")
    price = soup.find_all("td", class_="alignR itemviewColor06")
    
    title = soup.find("title").string.split(" ")[2:-1:]
    kakaku.title = str(" ".join(title))
    
    date_tmp = []
    price_tmp = []
    
    for i,j in zip(date[0::2],price):
        if(str(i.string)=="現在"):
            date_tmp.append(datetime.now().strftime('%Y-%m-%d'))
        else:
            date_tmp.append("".join(str(i.string).split(" ")[:-1:]).replace("年","-").replace("月","-").replace("日",""))
        price_tmp.append(int(str(j.string[1::]).replace(',','')))
    
    kakaku.date = date_tmp
    kakaku.price = price_tmp
    
"""
for i in kakaku_list:
    print(i.title)
    for j,k in zip(i.date,i.price):
        print(j,k)
    print()
    
"""
import pandas as pd
kakaku_Title = []
kakaku_Date = []
kakaku_Price = []

for i in kakaku_list:
    for j in range(len(i.date)):
        kakaku_Title.append(i.title)
    kakaku_Date += i.date
    kakaku_Price += i.price

kakaku_data = pd.DataFrame(
        {"Title":kakaku_Title,
         "Date":kakaku_Date,
         "Price":kakaku_Price})




import altair as alt

alt.Chart(kakaku_data, height=500 ,width=700).configure_legend(labelLimit=0).mark_line().encode(
        x="Date:T",
        y="Price:Q",
        color="Title:N"
        )
# Out:
# Chart({
#   config: Config({
#     legend: LegendConfig({
#       labelLimit: 0
#     })
#   }),
#   data:            Date  Price                                              Title
#   0    2019-04-01  11959  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   1     2019-3-31  11959  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   2     2019-3-31  11959  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   3     2019-3-30  11959  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   4     2019-3-21  11959  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   5     2019-3-21  11970  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   6     2019-3-17  11980  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   7     2019-3-12  11980  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   8     2019-3-11  12480  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   9     2019-3-11  12480  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   10     2019-3-8  12480  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   11     2019-3-8  12866  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   12    2019-2-18  12979  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   13     2019-2-1  12980  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   14     2019-2-1  12980  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   15     2019-2-1  13332  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   16    2019-1-31  13975  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   17    2019-1-30  13976  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   18    2019-1-28  13977  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   19    2019-1-25  13978  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   20    2019-1-22  13979  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   21    2019-1-18  13980  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   22     2019-1-8  14980  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   23     2019-1-8  16799  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   24     2019-1-8  16800  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   25     2019-1-8  18160  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   26     2019-1-7  18468  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   27     2019-1-7  15980  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   28     2019-1-7  15800  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   29     2019-1-7  15026  CFD CFD Selection W4U2666BMS-8G [DDR4 PC4-2130...
#   ..          ...    ...                                                ...
#   175    2019-3-1  10798                           ANTEC NeoECO Gold NE750G
#   176   2019-2-25  10799                           ANTEC NeoECO Gold NE750G
#   177   2019-2-25  10800                           ANTEC NeoECO Gold NE750G
#   178   2019-2-22  10800                           ANTEC NeoECO Gold NE750G
#   179   2019-2-11  11690                           ANTEC NeoECO Gold NE750G
#   180    2019-2-9  11693                           ANTEC NeoECO Gold NE750G
#   181    2019-2-4  11800                           ANTEC NeoECO Gold NE750G
#   182    2019-2-1  11600                           ANTEC NeoECO Gold NE750G
#   183    2019-2-1  10022                           ANTEC NeoECO Gold NE750G
#   184    2019-2-1   9980                           ANTEC NeoECO Gold NE750G
#   185   2019-1-31   9979                           ANTEC NeoECO Gold NE750G
#   186   2019-1-30   9979                           ANTEC NeoECO Gold NE750G
#   187   2019-1-30   9980                           ANTEC NeoECO Gold NE750G
#   188   2019-1-30   9979                           ANTEC NeoECO Gold NE750G
#   189   2019-1-30   9980                           ANTEC NeoECO Gold NE750G
#   190   2019-1-30   9979                           ANTEC NeoECO Gold NE750G
#   191   2019-1-30   9980                           ANTEC NeoECO Gold NE750G
#   192   2019-1-30   9979                           ANTEC NeoECO Gold NE750G
#   193   2019-1-29   9980                           ANTEC NeoECO Gold NE750G
#   194   2019-1-21   9115                           ANTEC NeoECO Gold NE750G
#   195   2019-1-19   9115                           ANTEC NeoECO Gold NE750G
#   196   2019-1-12   9880                           ANTEC NeoECO Gold NE750G
#   197    2019-1-3   8843                           ANTEC NeoECO Gold NE750G
#   198  2018-12-28   8843                           ANTEC NeoECO Gold NE750G
#   199  2018-12-22   8843                           ANTEC NeoECO Gold NE750G
#   200  2018-12-19   9032                           ANTEC NeoECO Gold NE750G
#   201   2018-12-8   9031                           ANTEC NeoECO Gold NE750G
#   202   2018-12-7   9032                           ANTEC NeoECO Gold NE750G
#   203   2018-12-7   9032                           ANTEC NeoECO Gold NE750G
#   204   2018-12-6   9032                           ANTEC NeoECO Gold NE750G
#
#   [205 rows x 3 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'Title:N'
#     }),
#     x: X({
#       shorthand: 'Date:T'
#     }),
#     y: Y({
#       shorthand: 'Price:Q'
#     })
#   }),
#   height: 500,
#   mark: 'line',
#   width: 700
# })
